# %% [markdown]
# # Evaluation

# %% [markdown]
# In this hackathon, you will use this notebook to evaluate the performance of your machine learning pipeline. The notebook is designed to assess the entire pipeline, from data preprocessing to making predictions, ensuring that your solution is practical, efficient, and accurate.

# %% [markdown]
# **Important Note:**
# - The evaluation runs on a `single` CPU core to ensure fair resource usage comparisons.
# - It assesses the pipeline’s performance as a whole, not just the final model’s predictions.

# %% [markdown]
# ---

# %% [markdown]
# ### 1. What the Evaluation Measures

# %% [markdown]
# The notebook evaluates your pipeline on several metrics:

# %% [markdown]
# #### **1.	Accuracy and Model Performance:**

# %% [markdown]
# - **Accuracy**: How many predictions were correct.
# - **F1 Score**: A balanced measure of precision and recall, especially for imbalanced datasets.
# - **Confusion Matrix**: A detailed breakdown of your model’s predictions across the following classes:
#     - `Priority`: The most important class, representing clear and usable images. Misclassifying these has the greatest negative impact.
# 	- `Noisy` & `Blurry`: Impure images that could potentially be recovered through preprocessing. Errors here are less critical but still significant.
# 	- `Corrupt` & `Missing_Data`: The least important classes, representing images with severe issues or no usable data. Misclassifications here have the smallest impact.

# %% [markdown]
# #### **2. Evaluation Time:**

# %% [markdown]
# - **What we measure**: How long your pipeline takes to preprocess the data and make predictions.
# - **Single CPU Core**: The evaluation runs on a `single` CPU core, not just for fairness, but to simulate a resource-constrained environment where computational resources are limited.
# - **Why it matters**: Faster pipelines are more practical and scalable, especially in environments with strict performance or resource limitations.

# %% [markdown]
# #### **3. Memory Usage:**

# %% [markdown]
# - **Peak Memory Usage:** Maximum memory used during pipeline execution.
# - **Average CPU Usage:** Percentage of a single core used throughout the process.
# - **Why it matters:** CubeSat will use a processor with limited memory, and the memory utilization must fit within available memory.

# %% [markdown]
# #### **4. Algorithm Code Size:**

# %% [markdown]
# - The total size of your pipeline, including the serialized model and preprocessing function, measured in megabytes (MB).
# - Algorithm code must fit within a limited available memory

# %% [markdown]
# ---

# %% [markdown]
# #### Import test data

# %%
import numpy as np  # For numerical computations and handling arrays efficiently
import pickle       # For serializing and deserializing Python objects (saving/loading models, data)
import joblib       # Optimized for saving/loading large objects like ML models and NumPy arrays efficiently

# first let us load the testing data
test_images = np.load('data/test_images.npy')      # Load image test data
test_labels = np.load('data/test_labels.npy')      # Load label test data

# %% [markdown]
# **Note:** You can also use this notebook to evaluate trained models on the validation set.

# %% [markdown]
# #### Import Evaluation function

# %%
from source.evaluate import evaluate_pipeline # A built-in function to evaluate a given ML pipeline by preprocessing, predicting, and calculating performance metrics.

# %% [markdown]
# **Inputs:**
#
# - **model**: The trained machine learning model to evaluate.
# - **X_test_raw**: Raw test data that needs to be preprocessed before evaluation.
# - **y_test**: True labels corresponding to the test data for performance comparison.
# - **preprocessing_fn**: A function used to preprocess the raw test data.
#
# **Outputs:**
#
# - **metrics**: A dictionary containing various evaluation metrics like accuracy, F1 score, evaluation time, memory usage, CPU usage, and algorithm code size.
# - **confusion matrix**

# %% [markdown]
# ---

# %% [markdown]
# ### 2. ML: Evaluation (3rd notebook)

# %% [markdown]
# #### Preprocessing (Testing data)

# %% [markdown]
# Applying consistent preprocessing to both training and testing data ensures accurate predictions, prevents mismatches, and improves model evaluation. Combining all steps into one function enhances consistency, tracks execution time, and optimizes resource usage.

# %%
def preprocessing_fn_ML(X): # We apply the same pre-processing steps implemented in Notebook 3.
    from skimage.color import rgb2gray
    from skimage.transform import resize
    
    # Normalize the data to [0, 1]
    X_pre = X.astype('float32') / 255.0
    
    # Convert to grayscale
    X_pre = np.array([rgb2gray(image) for image in X_pre])
    
    # Resize images to 64x64 pixels
    X_pre = np.array([resize(image, (72, 72), anti_aliasing=True) for image in X_pre])
    
    # Flatten the images
    num_samples = X_pre.shape[0]
    X_pre = X_pre.reshape(num_samples, -1)
    
    return X_pre

# %% [markdown]
# #### Import ML model

# %% [markdown]
# #### ML Evaluation

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost4.pkl', 'rb') as file:
    xgb4_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb4_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Starting preprocessing...
# Preprocessing completed.
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       51.16 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     13080.16 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     99.80 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.28 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.849 (The percentage of correctly classified samples.)
# F1 Score:              0.831 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost5.pkl', 'rb') as file:
    xgb5_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb5_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Starting preprocessing...
# Preprocessing completed.
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       6.16 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     6167.21 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     98.42 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.28 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.850 (The percentage of correctly classified samples.)
# F1 Score:              0.833 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost6.pkl', 'rb') as file:
    xgb6_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb6_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# ### Evaluation Metrics ###
#
# Evaluation Time:       6.33 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     6171.74 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     98.27 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.22 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.846 (The percentage of correctly classified samples.)
# F1 Score:              0.829 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the model
sgd7_model = joblib.load('models/SGD7.pkl')

# Evaluate the pipeline
metrics = evaluate_pipeline(sgd7_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Processing 3237 images...
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       25.57 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     6277.77 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     12.38 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.05 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.837 (The percentage of correctly classified samples.)
# F1 Score:              0.842 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost8.pkl', 'rb') as file:
    xgb8_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb8_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Processing 3237 images...
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       13.47 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     13581.23 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     99.27 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.38 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.888 (The percentage of correctly classified samples.)
# F1 Score:              0.884 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost9.pkl', 'rb') as file:
    xgb9_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb9_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Processing 3237 images...
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       12.32 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     13581.23 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     99.25 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.38 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.888 (The percentage of correctly classified samples.)
# F1 Score:              0.884 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the model
gb10_model = joblib.load('models/GradientBoosting10.pkl')

# Evaluate the pipeline
metrics = evaluate_pipeline(gb10_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Processing 3237 images...
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       16.14 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     13582.87 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     99.41 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.57 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.900 (The percentage of correctly classified samples.)
# F1 Score:              0.897 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost10.pkl', 'rb') as file:
    xgb10_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb10_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# Processing 3237 images...
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       16.50 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     6299.71 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     99.47 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.38 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.885 (The percentage of correctly classified samples.)
# F1 Score:              0.880 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %% [markdown]
# ### Model Performance:
#
# | Model               | Accuracy | F1 Score | CPU Usage (%) | Algorithm Code Size (MB) | Evaluation Time (s) |
# |---------------------|----------|----------|----------------|---------------------------|----------------------|
# | GradientBoosting10  | 0.900    | 0.897    | 99.41          | 0.57                      | 16.14                |
# | XGBoost9            | 0.888    | 0.884    | 99.25          | 0.38                      | 12.32                |
# | XGBoost8            | 0.888    | 0.884    | 99.27          | 0.38                      | 13.47                |
# | XGBoost5            | 0.850    | 0.833    | 98.42          | 0.28                      | 6.16                 |
# | XGBoost6            | 0.846    | 0.829    | 98.27          | 0.22                      | 6.33                 |
# | XGBoost4            | 0.849    | 0.831    | 99.80          | 0.28                      | 51.16                |
# | SGD7                | 0.837    | 0.842    | 12.38          | 0.05                      | 25.57                |
#
# ### Best Model for CubeSat Space Research
#
# The best model for CubeSat space research is **GradientBoosting10**
#
# 1. **Highest Accuracy**: GradientBoosting10 has the highest accuracy (0.900) among the models, which is crucial for reliable image classification in space research.
# 2. **Highest F1 Score**: GradientBoosting10 also has the highest F1 score (0.897), indicating a good balance between precision and recall, which is important for handling imbalanced datasets.
# 3. **Reasonable CPU Usage**: Although GradientBoosting10 has high CPU usage (99.41%), it is comparable to the other models and is acceptable given its superior performance.
# 4. **Moderate Algorithm Code Size**: The algorithm code size of GradientBoosting10 (0.57 MB) is manageable and suitable for deployment in environments with limited storage.
# 5. **Reasonable Evaluation Time**: The evaluation time of GradientBoosting10 (16.14 seconds) is reasonable and efficient for real-time applications.
#
# ### Discussion
#
# For CubeSat space research, the model needs to be highly accurate and efficient in terms of resource usage. GradientBoosting10 provides the best balance of high accuracy, high F1 score, and reasonable evaluation time, making it the most suitable choice for this task. Its moderate algorithm code size ensures that it can be deployed in environments with limited storage, which is often a constraint in space research. Overall, GradientBoosting10's superior performance and efficiency make it the best model for CubeSat image classification.

# %% [markdown]
# ---

# %% [markdown]
# ### 3. CubeSatNet_CNN Evaluation

# %% [markdown]
# #### preprocessing

# %%
def preprocessing_fn_CNN(X):  # we did not use any preprocessing in notebook 4

    return X

# %% [markdown]
# #### Import CNN model

# %%
from keras.utils import to_categorical
test_labels = to_categorical(test_labels, num_classes=5)

# Load the CNN model from the 4th notebook
with open('models_CNN/cnn_model.pkl', 'rb') as file:
    cnn_model = pickle.load(file)
# Out:
# 2025-01-08 16:25:19.067049: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-08 16:25:20.298813: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-08 16:25:20.643078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-08 16:25:21.398004: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-08 16:25:21.598407: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 16:25:22.310910: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-08 16:26:22.046561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### Evaluate the CNN pipeline

# %%
# Evaluate the pipeline
metrics = evaluate_pipeline(cnn_model, test_images, test_labels, preprocessing_fn_CNN)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       265.27 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     8455.79 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     89.29 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         1.16 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.998 (The percentage of correctly classified samples.)
# F1 Score:              0.998 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %% [markdown]
# ---

# %% [markdown]
# ##### **⚠️ Freeing up Space**

# %%
import gc

# Remove the data from memory
del sgd_model, cnn_model, test_images, test_labels

# Force garbage collection to free up memory
gc.collect()

# Clear the input/output cache
print("Data and models removed from memory.")
# Out:
# Data and models removed from memory.

# %% [markdown]
# ---

# %% [markdown]
# **Note:**
#
# 1.	You can also use the `evaluate_pipeline` function to evaluate your validation set data.
# 2.	Please do not modify the `evaluate_pipeline` function.
#
# Best of luck with the hackathon challenge! 🎉 We look forward to seeing your final results and pipelines! 🚀
