# %% [markdown]
# # Evaluation

# %% [markdown]
# In this hackathon, you will use this notebook to evaluate the performance of your machine learning pipeline. The notebook is designed to assess the entire pipeline, from data preprocessing to making predictions, ensuring that your solution is practical, efficient, and accurate.

# %% [markdown]
# **Important Note:**
# - The evaluation runs on a `single` CPU core to ensure fair resource usage comparisons.
# - It assesses the pipeline’s performance as a whole, not just the final model’s predictions.

# %% [markdown]
# ---

# %% [markdown]
# ### 1. What the Evaluation Measures

# %% [markdown]
# The notebook evaluates your pipeline on several metrics:

# %% [markdown]
# #### **1.	Accuracy and Model Performance:**

# %% [markdown]
# - **Accuracy**: How many predictions were correct.
# - **F1 Score**: A balanced measure of precision and recall, especially for imbalanced datasets.
# - **Confusion Matrix**: A detailed breakdown of your model’s predictions across the following classes:
#     - `Priority`: The most important class, representing clear and usable images. Misclassifying these has the greatest negative impact.
# 	- `Noisy` & `Blurry`: Impure images that could potentially be recovered through preprocessing. Errors here are less critical but still significant.
# 	- `Corrupt` & `Missing_Data`: The least important classes, representing images with severe issues or no usable data. Misclassifications here have the smallest impact.

# %% [markdown]
# #### **2. Evaluation Time:**

# %% [markdown]
# - **What we measure**: How long your pipeline takes to preprocess the data and make predictions.
# - **Single CPU Core**: The evaluation runs on a `single` CPU core, not just for fairness, but to simulate a resource-constrained environment where computational resources are limited.
# - **Why it matters**: Faster pipelines are more practical and scalable, especially in environments with strict performance or resource limitations.

# %% [markdown]
# #### **3. Memory Usage:**

# %% [markdown]
# - **Peak Memory Usage:** Maximum memory used during pipeline execution.
# - **Average CPU Usage:** Percentage of a single core used throughout the process.
# - **Why it matters:** CubeSat will use a processor with limited memory, and the memory utilization must fit within available memory.

# %% [markdown]
# #### **4. Algorithm Code Size:**

# %% [markdown]
# - The total size of your pipeline, including the serialized model and preprocessing function, measured in megabytes (MB).
# - Algorithm code must fit within a limited available memory

# %% [markdown]
# ---

# %% [markdown]
# #### Import test data

# %%
import numpy as np
# first let us load the testing data
test_images = np.load('data/test_images.npy')      # Load image test data
test_labels = np.load('data/test_labels.npy')      # Load label test data

# %% [markdown]
# **Note:** You can also use this notebook to evaluate trained models on the validation set.

# %% [markdown]
# #### Import Evaluation function

# %%
from source.evaluate import evaluate_pipeline # A built-in function to evaluate a given ML pipeline by preprocessing, predicting, and calculating performance metrics.

# %% [markdown]
# **Inputs:**
#
# - **model**: The trained machine learning model to evaluate.
# - **X_test_raw**: Raw test data that needs to be preprocessed before evaluation.
# - **y_test**: True labels corresponding to the test data for performance comparison.
# - **preprocessing_fn**: A function used to preprocess the raw test data.
#
# **Outputs:**
#
# - **metrics**: A dictionary containing various evaluation metrics like accuracy, F1 score, evaluation time, memory usage, CPU usage, and algorithm code size.
# - **confusion matrix**

# %% [markdown]
# ---

# %% [markdown]
# ### 2. ML: Evaluation (3rd notebook)

# %% [markdown]
# #### Preprocessing (Testing data)

# %% [markdown]
# Applying consistent preprocessing to both training and testing data ensures accurate predictions, prevents mismatches, and improves model evaluation. Combining all steps into one function enhances consistency, tracks execution time, and optimizes resource usage.

# %%
def preprocessing_fn_ML(X): # We apply the same pre-processing steps implemented in Notebook 3.
    from skimage.color import rgb2gray
    from skimage.transform import resize
    
    # Normalize the data to [0, 1]
    X_pre = X.astype('float32') / 255.0
    
    # Convert to grayscale
    X_pre = np.array([rgb2gray(image) for image in X_pre])
    
    # Resize images to 64x64 pixels
    X_pre = np.array([resize(image, (64, 64), anti_aliasing=True) for image in X_pre])
    
    # Flatten the images
    num_samples = X_pre.shape[0]
    X_pre = X_pre.reshape(num_samples, -1)
    
    return X_pre

# %% [markdown]
# #### Import ML model

# %%
import pickle
# Load the ml model from the 3rd notebook
with open('models/sgd_model.pkl', 'rb') as file:
    sgd_model = pickle.load(file)

# %% [markdown]
# #### ML Evaluation

# %%
# Assuming you have:
# - A trained model named like 'lr_model'
# - Raw test data 'X_test_raw'
# - True labels 'y_test'
# - All pre-processing methods gathered in one function


# Evaluate the pipeline
metrics = evaluate_pipeline(sgd_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# ### Evaluation Metrics ###
#
# Evaluation Time:       33.48 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     18649.16 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     99.35 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.08 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.452 (The percentage of correctly classified samples.)
# F1 Score:              0.387 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %% [markdown]
# ---

# %%
# Load the ml model from the 3rd notebook
with open('shared/models/XGBoost10.pkl', 'rb') as file:
    xgb10_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb10_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Load the ml model from the 3rd notebook
# ----> 2 with open('shared/models/XGBoost10.pkl', 'rb') as file:
#       3     xgb10_model = pickle.load(file)
#       5 # Evaluate the pipeline
#
# File /shared/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shared/models/XGBoost10.pkl'

# %%
import joblib
# Load the model
gb10_model = joblib.load('shared/models/GradientBoosting10.pkl')

# Evaluate the pipeline
metrics = evaluate_pipeline(gb10_model, test_images, test_labels, preprocessing_fn_ML)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       3 gb10_model = joblib.load('models/GradientBoosting10.pkl')
#       5 # Evaluate the pipeline
# ----> 6 metrics = evaluate_pipeline(gb10_model, test_images, test_labels, preprocessing_fn_ML)
#
# File /shared/source/evaluate.py:134, in evaluate_pipeline(model, X_test_raw, y_test, preprocessing_fn)
#     131 X_test_processed = preprocess_data(preprocessing_fn, X_test_raw)
#     133 # Make predictions
# --> 134 y_pred = make_predictions(model, X_test_processed)
#     136 # End timing
#     137 end_time = time.time()
#
# File /shared/source/evaluate.py:29, in make_predictions(model, X_test_processed)
#      28 def make_predictions(model, X_test_processed):
# ---> 29     return model.predict(X_test_processed)
#
# File /shared/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:1611, in GradientBoostingClassifier.predict(self, X)
#    1596 def predict(self, X):
#    1597     """Predict class for X.
#    1598
#    1599     Parameters
#    (...)
#    1609         The predicted values.
#    1610     """
# -> 1611     raw_predictions = self.decision_function(X)
#    1612     if raw_predictions.ndim == 1:  # decision_function already squeezed it
#    1613         encoded_classes = (raw_predictions >= 0).astype(int)
#
# File /shared/venv/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:1564, in GradientBoostingClassifier.decision_function(self, X)
#    1545 def decision_function(self, X):
#    1546     """Compute the decision function of ``X``.
#    1547
#    1548     Parameters
#    (...)
#    1562         array of shape (n_samples,).
#    1563     """
# -> 1564     X = self._validate_data(
#    1565         X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#    1566     )
#    1567     raw_predictions = self._raw_predict(X)
#    1568     if raw_predictions.shape[1] == 1:
#
# File /shared/venv/lib/python3.10/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File /shared/venv/lib/python3.10/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 4096 features, but GradientBoostingClassifier is expecting 150 features as input.

# %%
# Load the ml model from the 3rd notebook
with open('shared/models/XGBoost9.pkl', 'rb') as file:
    xgb9_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb9_model, test_images, test_labels, preprocessing_fn_ML)

# %%
# Load the ml model from the 3rd notebook
with open('models/XGBoost8.pkl', 'rb') as file:
    xgb8_model = pickle.load(file)

# Evaluate the pipeline
metrics = evaluate_pipeline(xgb8_model, test_images, test_labels, preprocessing_fn_ML)

# %% [markdown]
# ### 3. CubeSatNet_CNN Evaluation

# %% [markdown]
# #### preprocessing

# %%
def preprocessing_fn_CNN(X):  # we did not use any preprocessing in notebook 4

    return X

# %% [markdown]
# #### Import CNN model

# %%
import pickle

# %%
from keras.utils import to_categorical
test_labels = to_categorical(test_labels, num_classes=5)

# Load the CNN model from the 4th notebook

with open('models/cnn_model_full_separableConv2D_V1.pkl', 'rb') as file:
    cnn_model = pickle.load(file)
# Out:
# 2025-03-07 09:32:07.333637: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-07 09:32:07.337937: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-07 09:32:07.347668: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741332727.363659  134904 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741332727.368179  134904 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-07 09:32:07.385779: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-07 09:32:08.974386: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
print("test_images shape:", test_images.shape)  # Should be (num_samples, height, width, channels)
print("test_labels shape:", test_labels.shape)  # Should be (num_samples, 5)
# Out:
# test_images shape: (3237, 512, 512, 3)
# test_labels shape: (3237, 5)

# %% [markdown]
# #### Evaluate the CNN pipeline

# %% [markdown]
# #### 1. Evaluation for the SepConv2D Model our base model

# %%
# Evaluate the pipeline 
metrics = evaluate_pipeline(cnn_model, test_images, test_labels, preprocessing_fn_CNN)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 44s 425ms/step
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       85.33 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     8298.73 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     54.32 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.19 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.998 (The percentage of correctly classified samples.)
# F1 Score:              0.998 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %% [markdown]
# #### 2. Evaluation for the Pruned SepConv2D Model

# %%
# Evaluate the pipeline
metrics = evaluate_pipeline(cnn_model, test_images, test_labels, preprocessing_fn_CNN)
# Out:
# 102/102 [==============================] - 42s 410ms/step
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       86.53 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     8093.76 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     52.69 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.08 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.998 (The percentage of correctly classified samples.)
# F1 Score:              0.998 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %% [markdown]
# #### 3. Evaluation for the final Optimized model using tensorflow lite

# %%
# For a regular TensorFlow model (your existing code)
# metrics = evaluate_pipeline(cnn_model, test_images, test_labels, preprocessing_fn_CNN)

# For a TFLite model (new capability)

# metrics = evaluate_pipeline('models/cnn_model_full_SepConv2D_quantized_model_V1.tflite', 
#                             test_images, test_labels, preprocessing_fn_CNN)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# ### Evaluation Metrics ###
#
# Evaluation Time:       6.82 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     3783.05 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     98.26 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:   0.03 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.997 (The percentage of correctly classified samples.)
# F1 Score:              0.997 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %%
# Evaluate the pipeline
# metrics = evaluate_pipeline(cnn_model, test_images, test_labels, preprocessing_fn_CNN)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 42s 406ms/step
#
# ### Evaluation Metrics ###
#
# Evaluation Time:       84.98 seconds (The time it took for the pipeline to preprocess data and make predictions.)
# Peak Memory Usage:     8302.65 MB (The maximum memory used during evaluation.)
# Average CPU Usage:     52.01 % (The % shows how much of one CPU core was used during the evaluation.)
# Algorithm code size:         0.19 MB (The size of the trained model and preprocessing function.)
# Accuracy:              0.998 (The percentage of correctly classified samples.)
# F1 Score:              0.998 (A balance of precision and recall, useful for imbalanced datasets.)
#
# ### Confusion Matrix ###

# %% [markdown]
# ---

# %% [markdown]
# ##### **⚠️ Freeing up Space**

# %%
import gc

# Remove the data from memory
del sgd_model, cnn_model, test_images, test_labels

# Force garbage collection to free up memory
gc.collect()

# Clear the input/output cache
print("Data and models removed from memory.")
# Out:
# Data and models removed from memory.

# %% [markdown]
# ---

# %% [markdown]
# **Note:**
#
# 1.	You can also use the `evaluate_pipeline` function to evaluate your validation set data.
# 2.	Please do not modify the `evaluate_pipeline` function.
#
# Best of luck with the hackathon challenge! 🎉 We look forward to seeing your final results and pipelines! 🚀
